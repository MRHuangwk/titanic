# %%
import pandas as pd
import numpy as np

titanic = pd.read_csv('./kaggle/input/titanic/train.csv')

# %%
titanic.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B1A5420EC8>,
# ...
#       dtype=object)

# %%
train_csv.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
len(_)
# Out:
# 12

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
y = titanic['Survived']

# %%
y.shape
# Out:
# (891,)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
from pandas.plotting import scatter_matrix
attributes = ["Survived", "Age", "Sex",
"Pclass", "SibSp", "Parch", "Fare"]
scatter_matrix(titanic[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B1A8A37308>,
# ...
#       dtype=object)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(titanic,
titanic["Sex"]):
    strat_train_set = titanic.loc[train_index]
    strat_test_set = titanic.loc[test_index]

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
strat_train_set
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 788          789         1       3                 Dean, Master. Bertram Vere
# 347          348         1       3  Davison, Mrs. Thomas Henry (Mary E Finck)
# 629          630         0       3                   O'Connell, Mr. Patrick D
# 734          735         0       2               Troupiansky, Mr. Moses Aaron
# 106          107         1       3           Salkjelsvik, Miss. Anna Kristine
# ..           ...       ...     ...                                        ...
# 263          264         0       1                      Harrison, Mr. William
# 628          629         0       3                  Bostandyeff, Mr. Guentcho
# 711          712         0       1                         Klaber, Mr. Herman
# 453          454         1       1                   Goldenberg, Mr. Samuel L
# 261          262         1       3          Asplund, Master. Edvin Rojj Felix
#
# ...

# %%
strat_train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 788 to 261
# Data columns (total 12 columns):
# PassengerId    712 non-null int64
# Survived       712 non-null int64
# Pclass         712 non-null int64
# Name           712 non-null object
# Sex            712 non-null object
# Age            578 non-null float64
# SibSp          712 non-null int64
# Parch          712 non-null int64
# Ticket         712 non-null object
# Fare           712 non-null float64
# Cabin          164 non-null object
# Embarked       710 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.3+ KB

# %%
strat_train_set['Sex'] == 'male'
# Out:
# 788     True
# 347    False
# 629     True
# 734     True
# 106    False
#        ...
# 263     True
# 628     True
# 711     True
# 453     True
# 261     True
# Name: Sex, Length: 712, dtype: bool

# %%
titanic = strat_train_set.copy()

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class MakeNumAttr(BaseEstimator, TransformerMixin):
    def __init__(self, num_attr = ['Pclass','Age','SibSp','Parch','Fare']): # no *args or **kargs
        self.num_attr = num_attr
    def fit(self, X, y=None):
        return self # nothing else to do
    def transform(self, X, y=None):
        num_attr = pd.get_dummies(X[self.num_attr])
        return num_attr

# %%
titanic_num = MakeNumAttr().transform(titanic)

# %%
titanic_num
# Out:
#      Pclass   Age  SibSp  Parch     Fare
# 0         3  22.0      1      0   7.2500
# 1         1  38.0      1      0  71.2833
# 2         3  26.0      0      0   7.9250
# 3         1  35.0      1      0  53.1000
# 4         3  35.0      0      0   8.0500
# ..      ...   ...    ...    ...      ...
# 886       2  27.0      0      0  13.0000
# 887       1  19.0      0      0  30.0000
# 888       3   NaN      1      2  23.4500
# 889       1  26.0      0      0  30.0000
# 890       3  32.0      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
num_pipeline = Pipeline([
('make_num_attr', MakeNumAttr()),
('imputer', SimpleImputer(strategy="median")),
('std_scaler', StandardScaler()),
])
titanic_num_tr = num_pipeline.fit_transform(titanic)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
num_attribs = ['Pclass','Age','SibSp','Parch','Fare']
cat_attribs = ["Sex"]
full_pipeline = ColumnTransformer([
("num", num_pipeline, num_attribs),
("cat", OneHotEncoder(), cat_attribs),
])
titanic_prepared = full_pipeline.fit_transform(titanic)

# %%
titanic_label = titanic['Survived']

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(titanic_prepared, titanic_label)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#               early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#               l1_ratio=0.15, learning_rate='optimal', loss='hinge',
#               max_iter=1000, n_iter_no_change=5, n_jobs=None, penalty='l2',
#               power_t=0.5, random_state=42, shuffle=True, tol=0.001,
#               validation_fraction=0.1, verbose=0, warm_start=False)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(sgd_clf, titanic_prepared, titanic_label, cv=3, scoring="accuracy")
# Out:
# array([0.78787879, 0.8013468 , 0.79124579])

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=42)
rf_clf.fit(titanic_prepared, titanic_label)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(rf_clf, titanic_prepared, titanic_label, cv=3, scoring="accuracy")
# Out:
# array([0.77777778, 0.84175084, 0.81818182])

# %%
from sklearn.svm import SVC
svm_clf = SVC(verbose = True)
svm_clf.fit(titanic_prepared, titanic_label)
# Out:
# [LibSVM]
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=True)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(svm_clf, titanic_prepared, titanic_label, cv=3, scoring="accuracy")
# Out:
# [LibSVM][LibSVM][LibSVM]
# array([0.8047138 , 0.84175084, 0.83164983])

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_clf = KNeighborsClassifier(weights='distance', n_neighbors = 4)
knn_clf.fit(titanic_prepared, titanic_label)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='distance')

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(knn_clf, titanic_prepared, titanic_label, cv=3, scoring="accuracy")
# Out:
# array([0.74410774, 0.81481481, 0.76767677])

# %%
test_data = pd.read_csv('./kaggle/input/titanic/test.csv')
X_test = full_pipeline.fit_transform(test_data)

# %%
predictions = svm_clf.predict(X_test)

output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
output.to_csv('./kaggle/output/titanic/my_submission.csv', index=False)
